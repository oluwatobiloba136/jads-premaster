# %% [markdown]
# # week 1

# %%
#  guessing game
from random import randint
from IPython.display import clear_output
guessed = False
number = randint(0,100)
guesses = 0
"""
test comment
"""
while not guessed:
    ans = input("Try to guess the number I am thinking of!")
    guesses += 1
    clear_output()
    if int(ans) == number:
        print("Congrat! you guessed it correctly")
        print("it took you {} guesses".format(guesses))
        break
    elif int(ans) > number:
        print("The number is lower than what you guessed")
    elif int(ans) < number:
        print("The number is greater than what you guessed")

# %%
x = 3; y=10; result = x*y 
print(str(x) + ' + ' + str(y) + ' = ' + str(result))
print(result)

"""
string format
"""
name = "john"
print("hello {}".format(name))
print("hello {}, you are  {} yrs old!".format(name,28))
print(f'Hello {name}')
# Out:
# 3 + 10 = 30
# 30
# hello john
# hello john, you are  28 yrs old!
# Hello john

# %%
name = "     jogn       "
print(len(name))
print(len(name.strip()))
print(len(name.lstrip()))
# Out:
# 16
# 4
# 11

# %%
str_test = 'uppercase'
str_test.upper()
dol = '$$John Smith'
print(dol.lstrip('$$'))
# Out:
# John Smith

# %%
help(''.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %% [markdown]
# ![im](./img/wk2-project.png)

# %%
# Create company information
company_name = 'Coding Temple, Inc.'
company_add = '283 Franklin St.'
company_city = 'Boston, MA'

# Create product details
p1_name, p1_price = 'Books',49.95
p2_name, p2_price = 'Computer',579.99
p3_name, p3_price = 'Monitor', 124.89

#  declare the otuput message
mesg = 'Thanks for shopping with us today!'

# top and bottom edge
t_b_border = '*'*50
middle_lines = '='*50

"""
Display output
"""
print(t_b_border)
print(f'\t\t{company_name}')
# Out:
# **************************************************
# 		Coding Temple, Inc.

# %%
print('{} is my favorite sport'.format('football'))
# Out:
# football is my favorite sport

# %%
try:
    ans = float(input('Type a number to add: '))
    print(f'100 + {ans} ={100+ans}')
except:
    print('You did not put in a valid number!')
# Out:
# 100 + 45.0 =145.0

# %%
x,y =5,10
if x < y:
    print('x is less than y')

x,y,z = 5,10,5
if x<y or x !=z:
    print('One or both statements were true')
# Out:
# x is less than y
# One or both statements were true

# %%
flag = False
if not flag:  # same as saying if not true
    print('Flag is False')

word ='Baseball'
if 'b' in word:
    print(f'{word} contains the character b')
# Out:
# Flag is False
# Baseball contains the character b

# %%
x,y = 5, 10
if x>y:
    print('x is greater')
elif (x+10) <y: 
    print('x is less')
elif (x+5) == y:
    print('equal')
# Out:
# equal

# %%
nums  = [5,10,15.2,20]
print(nums)

data = [5,'book',[34,'hello'], True]
print(data)
print(data[2][1])
# Out:
# [5, 10, 15.2, 20]
# [5, 'book', [34, 'hello'], True]
# hello

# %%
data_copy = data[:] # or .copy() method

# %%
data_copy #90644900601
# Out:
# [5, 'book', [34, 'hello'], True]

# %%
for num in range(2,10,2):
    print(f'Value:{num}')
# Out:
# Value:2
# Value:4
# Value:6
# Value:8

# %%
for num in range(5):
    if num == 3:continue
    print(num)

    # break 
for num in range(5):
    if num == 3:
        break
    print(num)

for i in range(5):
    pass
# Out:
# 0
# 1
# 2
# 4
# 0
# 1
# 2

# %%
# nested loop 
for i in range(2):
    for j in range(3):
        print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
items = [5, 'ball', True]
items.pop()
removed_item = items.pop(0)
print(removed_item, '\n', items)
# Out:
# 5
#  ['ball']

# %%
sports = ['baseball', 'soccer', 'football', 'hockey']
try:
    sports.remove('soccer')
except:
    print('That items does not exist in the lsit')
print(sports)
# Out:
# ['baseball', 'football', 'hockey']

# %%
nums = [5, 0, 8, 3]
nums.sort()
print(nums)
# Out:
# [0, 3, 5, 8]

# %%
from random import choice
from IPython.display import clear_output
words = ['tree', 'basket', 'chair', 'paper', 'python']
word = choice(words)
guessed, lives, game_over = [], 7, False
guesses = ['_']*len(word)

while not game_over:
    ans = input('Type quit or quess a letter: ').lower()
    if ans == 'quit':
        game_over =True

# %%
def outputData(name, *args):
    print(type(args))
    for arg in args:
        print(arg)

outputData("John Smith", 5, True, 'Jess')
# Out:
# <class 'tuple'>
# 5
# True
# Jess

# %%
def output3Data(**kwargs):
    print(type(kwargs))
    print(kwargs["name"])
    print(kwargs["num"])

output3Data(name = 'John Smith', num=5, b = True)
# Out:
# <class 'dict'>
# John Smith
# 5

# %%
def searchList(aList, el):
    return True if el in aList else False

searchList(['one',2,'three'],2)
# Out:
# True

# %%
number = 5
def scopeTest():
    word = 'function'
    return word

scopeTest()
# Out:
# 'function'

# %% [markdown]
# **Friday: Creating a Shopping Cart**
#
# For today’s project, we’re going to build an application that stores products within a list.
# We’ll be able to
#  _add_,
#  _remove_,
#  _clear_, and show the products in the cart. All the concepts
# taught throughout the past few weeks will be used

# %%
# import necessary functions
from IPython.display import clear_output
cart = [] #declare a global list to products the user picked 

'''
Adding Items
'''
def addItem(item):
    clear_output()
    cart.append(item)
    print(f'{item} has been added.')


'''
Removing Items
'''

def removeItem(item):
    clear_output()
    try: 
        cart.remove(item)
        print(f'{item} has been removed')
    except: print('Sorry we could not remove that item')


'''
Showing Cart
'''

def showCart():
    clear_output()
    if cart: print('Here is your cart:')
    for item in cart: print(f'- {item}')
    else: print('Your cart is empty')


'''
Clearing the cart
'''

def clearCart():
    clear_output()
    cart.clear()
    print('Your cart is emppty')


def main():
    done = False
    while not done:
        ans = input('quit/add/remove/show/clear: ').lower()
        if ans == 'quit': 
            print('Thanks for using our program')
            showCart()
            done = True
        elif ans == 'add':
            item = input('What would you like to add? ').title()
            addItem(item)
        elif ans == 'remove':
            showCart()
            item = input("What item would you like to remove?").title()
            removeItem(item)
        elif ans == 'show':
            showCart()
        elif ans == 'clear':
            clearCart()
        else: 
            print("Sorry that was not an option.")
main()
# Out:
# Here is your cart:
# - Biscuit
# - Sweet
# Your cart is empty

# %%
person = {'name': 'John', 'age':26}
s1 = set([1,2,3,1])
s1

fset = frozenset([1,2,3])
fset
# Out:
# frozenset({1, 2, 3})

# %% [markdown]
# For this week’s project, we’ll be building a replica of a user database with CSV files. We’ll
# be able to take input and allow users to log in/log out/register

# %% [markdown]
# ### Program Flowchart
#
# 1. Check to see if user is logged in.
#
#     a. If logged in, ask if they would like to log out/quit.
#
#         i. Either quit or log out user and restart.
#
#     b. Else, ask if they would like to log in/register/quit.
#
#         i. If log in, ask user for e-mail/password.
#
#             1. If correct, log user in and restart.
#
#             2. Else, display error and restart.
#
#         ii. If register, ask for e-mail/password/password2.
#
#             1. If passwords match, save user and restart.
#
#             2. Else, display error and restart.
#
#         iii. If quit, say thank you and exit program

# %%
#  import all necessary packages to be used

import csv
from IPython.display import clear_output


########################################
#           BACKEND                    #
'''
Registering users
'''
# handle user registratio and writing to csv
def registerUser():
    with open('users.csv', mode='a', newline='') as f:
        writer = csv.writer(f, delimiter=',')
        print('To register, please enter your info:')
        email = input('E-mail: ')
        password = input('Password: ')
        password2 = input('Re-type password: ')
        clear_output()
        if password == password2: 
            writer.writerow([email, password])
            print('You are now registered!')
        
        else: print('Something went wrong. Try again')


'''
Handling user login
'''

def loginUser():
    print('To login, please enter your info')
    email = input('E-mail: ')
    password = input('Password: ')
    clear_output()
    with open('users.csv', mode='r') as f:
        reader = csv.reader(f, delimiter=',')
        for row  in reader:
            if row == [email, password]:
                print('You are now logged in!')
                # if the user is found
                return True
    # if the user is not found at the end of the loop
    print('Something went wrong, try again')
    return False

########################################
#          FRONTEND                    #
'''
Main Loop
for Handling of the menu system and what to
show based on the user being logged in or not
'''

#  variables for main loop
active   = True
logged_in = False

while active:
    if logged_in:
        print("1. Logout\n2. Quit")
    else: 
        print('1. Login\n2. Register\n3. Quit')
    choice = input('What would you like to do?').lower()
    clear_output()
    if choice == 'register' and logged_in == False:
        registerUser()
    elif choice == 'login' and logged_in == False:
        logged_in = loginUser()
    elif choice == 'quit':
        active = False
        print('Thanks for using our software!')
    elif choice == 'logout' and logged_in == True:
        logged_in = False
        print('You are now logged out.')
    else:
        print('Sorry, please try again!')

# %%
# # 22318168773
# 08077566058
#  https://www.gatevidyalay.com/tag/k-means-clustering-flowchart/
